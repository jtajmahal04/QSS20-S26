# %%
# Read Documentation, list variables you want to extract
# Make API calls to save results in data frame
# Merge on state level with ACS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/tdawg/Desktop/Dartmouth/QSS/QSS 20/Final Project/Milestone 1/acs_wmath (3).csv")
df.head()
# Out:
#    math_female_2013  math_female_2015  math_female_2017  math_female_2019  \
# 0        281.388243        280.879362        276.557200        271.915723
# 1        268.920112        266.810672        266.748589        270.473059
# 2        278.381788        274.793326        273.139254        276.007484
# 3        279.249581        282.593875        279.935438        280.527631
# 4        274.597824        275.638637        276.669430        276.721824
#
#    math_male_2013  math_male_2015  math_male_2017  math_male_2019 abbrev  \
# 0      281.723376      280.143705      277.451445      276.639877     AK
# 1      269.457456      266.304405      269.820070      267.093325     AL
# 2      277.457662      275.325959      274.352754      272.827299     AR
# 3      280.174389      283.229891      284.522633      279.359156     AZ
# 4      277.167171      275.020977      276.608704      274.511628     CA
#
#    FIPS  ...  \
# 0     2  ...
# 1     1  ...
# 2     5  ...
# 3     4  ...
# ...

# %%
# I want to clean up the column names to remove filler words, underscores, and columns that won't be relevant to my final visualizations

# %%
# NEXT WE NEED TO MAKE THE NAEP API

# %%
# Select columns that I want from NAEP API
# Those being SLUNCH3, SRACE11, GENDER, PARED, SCHTYPE, CENSREG, 
#I want this to also be sorted by state results, so that I can merge it cleanly with ACS

#Clean up column names of ACS

# %%
#Do the API
#Show me the data frame you've then created with clean data names and columns

# %%
# THEN MERGE THE DATASETS!!!!

# %%
# Please return the final data frame
